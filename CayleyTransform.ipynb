# %% [markdown]
# # Section 3.2
#
# Analysing properties of the Cayley transform.

# %%
import src.CayleyTransform as CayleyTransform
import src.CommunitiesGraph as CommunitiesGraph

# %%
# Reload when files are changed
import importlib
importlib.reload(CayleyTransform)
importlib.reload(CommunitiesGraph)
# Out:
# <module 'src.CommunitiesGraph' from '/home/infres/avalenca-22/CayleyNets/src/CommunitiesGraph.py'>

# %%
# Cayley transform of the real line
import numpy as np
phi = np.linspace(start=1e-5, stop=1-1e-5, num=1000)*2*np.pi
z = np.exp(1j*phi)
x = CayleyTransform.ScalarCayleyTranform.inverse_cayley_transform(z).real

CayleyTransform.ScalarCayleyTranform.plot(x, save=True)

# TODO:
# - generate equally spaced points on the circle and apply inverse cayley transform for better visualization
# - used angles for colobar but correct tick labels

# %%
points = np.array([0, 1e-2, 1, 10, 1e4, 1e5])
CayleyTransform.ScalarCayleyTranform.plot(points)

# %%
n_community=15
p=0.5
q=0.001
n=1000
graph = CommunitiesGraph.CommunitiesGraph(n_community, p, q, n)

# %%
graph.display()

# %%
CT = CayleyTransform.CayleyTransform(graph.adjacency)

# %%
CT.plot_spectrum(15, save=True)

# %%
CT.transform(h=1)
CT.plot_transformed_spectrum(15, save=True, figname='cayley_spectrum_h1e0.png')

# %%
CT.transform(h=0.1)
CT.plot_transformed_spectrum(15, save=True, figname='cayley_spectrum_h1e-1.png')

# %%
CT.transform(h=10)
CT.plot_transformed_spectrum(15, save=True, figname='cayley_spectrum_h1e1.png')
